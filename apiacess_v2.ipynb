# %%
import requests
import os
from glob import glob
import json
f=open('audio_references.csv','r')
data=f.read().split('\n')
f.close()
data=data[1:]
print (data[len(data)-2:])



id_list = [37802, 37803, 37804, 37805]
headers = {
        'Authorization': "Bearer lljXCMX3PHZNvrf8eApNvDtF4rSMdMKcSmUe0Ivtu6e0OT6tDCbQXqQ63XxD-9IlxYaDivYqTTGCqk3LjmSgB2rZJuz9-2EjPlwzYgf0LkM3S4kWDD29BEiQJkMFa3-FFrANI6cB_Y7SPdF4d1nv4ZpQpsNn0cjw8hC4_Heu0IREJk7aGiY_vEecPp_iksm9W3Ew-ZNpem7M0r90-QKcRLb28QQlFoe5QeohrvlsRkcfBK_qhoU-HXWXfMmewVihpXpL1w3IZpPv4yB5dLX2z2rth88BDM3pTYNU22KCVn3vToaO4rvw7imzi5dtwm53PMoJCLNQl33qyH55wp6YCX3ORi_U5WlBWUSfrKPYb5nGn08DqwPImCQ2ddg5_xsSTgi9_SjCNB9vwzXKTox6iGz-Ro8TRHa7y_B7MzppZwOPJJq634Iv1qHOSjMZO5Vl",
        'content-type': 'multipart/form-data'
        }
import time
problems=[]
for x in data[:(len(data)-1)]:
    
    l=x.split('____')
    filetype=l[0]
    i=l[2]
    
    if i.find('API calls')!=-1:
        continue
    post_url = "https://admin.gweekspeech.com/api/v2/analysis/" + str(i)
    data1 = requests.request("GET", url = post_url, headers=headers)
    filename = filetype+'_' + str(i)
    
    checkdata=json.loads(data1.text)
    if 'Message' in checkdata:
        if checkdata['Message']=='Invalid recording id':
            problems.append(x)
            print ("Problem with "+str(x))
            continue
    print(filetype,i)
    with open((filename + '.json'), 'w') as f:
        json.dump(data1.text, f)
# Out:
# ['TED____AndrewBastawrous_2014U_4.wav____38451', '']
# Problem with AUDIOBOOKS____1447-130552_2.wav____37930
# Problem with AUDIOBOOKS____229-130880_5.wav____37931
# Problem with AUDIOBOOKS____5703-47212_2.wav____37932
# Problem with AUDIOBOOKS____5867-48852_11.wav____37933
# Problem with AUDIOBOOKS____6925-80680_9.wav____37934
# Problem with AUDIOBOOKS____8465-246942_2.wav____37935
# Problem with AUDIOBOOKS____8014-112602_2.wav____37936
# Problem with AUDIOBOOKS____26-495_3.wav____37937
# Problem with AUDIOBOOKS____426-122821_4.wav____37938
# Problem with AUDIOBOOKS____1363-139304_1.wav____37939
# Problem with AUDIOBOOKS____4051-10927_3.wav____37940
# Problem with AUDIOBOOKS____6081-41997_2.wav____37941
# Problem with AUDIOBOOKS____298-126791_6.wav____37942
# Problem with AUDIOBOOKS____6181-216552_13.wav____37943
# Problem with AUDIOBOOKS____1992-141719_1.wav____37944
# Problem with AUDIOBOOKS____3112-9555_2.wav____37945
# Problem with AUDIOBOOKS____233-155990_3.wav____37946
# ...

# %%
f=open('audio_references_fixed.csv','r')
data=f.read().split('\n')
f.close()

data=data[1:]
print (data[len(data)-2:])



id_list = [37802, 37803, 37804, 37805]
headers = {
        'Authorization': "Bearer lljXCMX3PHZNvrf8eApNvDtF4rSMdMKcSmUe0Ivtu6e0OT6tDCbQXqQ63XxD-9IlxYaDivYqTTGCqk3LjmSgB2rZJuz9-2EjPlwzYgf0LkM3S4kWDD29BEiQJkMFa3-FFrANI6cB_Y7SPdF4d1nv4ZpQpsNn0cjw8hC4_Heu0IREJk7aGiY_vEecPp_iksm9W3Ew-ZNpem7M0r90-QKcRLb28QQlFoe5QeohrvlsRkcfBK_qhoU-HXWXfMmewVihpXpL1w3IZpPv4yB5dLX2z2rth88BDM3pTYNU22KCVn3vToaO4rvw7imzi5dtwm53PMoJCLNQl33qyH55wp6YCX3ORi_U5WlBWUSfrKPYb5nGn08DqwPImCQ2ddg5_xsSTgi9_SjCNB9vwzXKTox6iGz-Ro8TRHa7y_B7MzppZwOPJJq634Iv1qHOSjMZO5Vl",
        'content-type': 'multipart/form-data'
        }
import time
import os
files=os.listdir(os.getcwd())
files=[x for x in files if x.find('.json')!=-1]
# Out:
# ['TED____BenoitMandelbrot_2010_3.wav____39411', '']

# %%
import requests
import json
problems=[]
import os
ignore_files=os.listdir(os.getcwd())
ignore_files=[x.split('_')[1].split('.')[0] for x in ignore_files if x.find('.json')!=-1]

# %%
for x in data[:(len(data)-1)]:
    l=x.split('____')
    filetype=l[0]
    i=l[2]
    if str(i) in ignore_files:
        print("File already there"+ str(i))
        continue
    
    if i.find('API calls')!=-1:
        continue
    post_url = "https://admin.gweekspeech.com/api/v2/analysis/" + str(i)
    data1 = requests.request("GET", url = post_url, headers=headers)
    filename = filetype+'_' + str(i)
    try:
        
        checkdata=json.loads(data1.text)
        if 'Message' in checkdata:
            if checkdata['Message']=='Invalid recording id':
                problems.append(x)
                print ("Problem with "+str(x))
                continue
        print(filetype,i)
        with open((filename + '.json'), 'w') as f:
            json.dump(data1.text, f)
    except:
        print ("issue")
        continue
# Out:
# File already there38481
# File already there38482
# File already there38483
# File already there38484
# Problem with AUDIOBOOKS____1355-39947_12.wav____38485
# File already there38486
# File already there38487
# File already there38488
# File already there38489
# File already there38490
# File already there38491
# File already there38492
# File already there38493
# File already there38494
# File already there38496
# File already there38498
# File already there38499
# File already there38500
# File already there38501
# File already there38502
# File already there38503
# Problem with TED____AmyGreen_2017S_6.wav____38504
# File already there38505
# File already there38506
# File already there38507
# File already there38508
# File already there38509
# File already there38510
# Problem with AUDIOBOOKS____6147-34607_5.wav____38511
# File already there38512
# File already there38513
# File already there38515
# File already there38516
# File already there38517
# File already there38518
# ...

# %%
f=open('Problem_ids.csv','w')
f.write('type____filename____id\n')
for x in problems:
    f.write(x)
    f.write('\n')
f.close()
